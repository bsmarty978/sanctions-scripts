# %%
import requests
import json

# %%
#API SETU ACCESS:
Clinet_ID  = "com.solyticspartners"
API_KEY = "6KklrKbP7QrbMFj728xOv7G1htqq8e9t"
Domain = "http//sams-solytics.com/"
App_ID = "886611"

url = "https://apisetu.gov.in/mca/v1"

headers = {
    'accept': 'application/json',
    'X-APISETU-APIKEY': '6KklrKbP7QrbMFj728xOv7G1htqq8e9t',
    'X-APISETU-CLIENTID': 'com.solyticspartners',
    }
def Get_MasterData_From_CIN(passcin):
    try:
        r = requests.get(f'https://apisetu.gov.in/mca/v1/companies/{passcin}',headers= headers)
        # print(r)
        # print(r.json())
        # print('----')
        return r.json()
    except:
        return {}

def Get_Director_From_CIN(passcin):
    try:
        r = requests.get(f'https://apisetu.gov.in/mca/v1/companies/{passcin}/directors',headers= headers)
        # print(r)
        # print(r.url)
        # print(r.json())
        return r.json()
    except:
        return {}

# %%
Get_MasterData_From_CIN("U17120MH1990PTC055377")
# Out:
# {'cin': 'U17120MH1990PTC055377',
#  'companyName': 'KANDOI FABRICS PRIVATE LIMITED',
#  'companyStatus': 'Active',
#  'email': 'finance@damanpolyfabs.com',
#  'financialAuditStatus': 'YES',
#  'incorporationDate': '12/02/1990',
#  'registeredAddress': '406, 4TH FLOOR, 33-A, LOTUS HOUSE, NEW MARINE LINES, MUMBAI MH 400020 IN',
#  'registeredContactNo': '',
#  'rocCode': 'RoC-Mumbai',
#  'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#    'turnOver': 'NOT APPLICABLE',
#    'year': '2021'},
#   {'profitLoss': '               0.00',
#    'turnOver': '      1708119138.42',
#    'year': '2020'},
#   {'profitLoss': '               0.00',
#    'turnOver': '      2037927252.10',
#    'year': '2019'}]}

# %%
import pymongo
client = pymongo.MongoClient("mongodb+srv://smt_mca_admin:smtMCA%40886611@mca-cluster.kdxoh.mongodb.net/?retryWrites=true&w=majority")
db = client["MCA-MASTER-DATA"]

# %%
list_of_CIN = []
counter  = 1
for data in db.mcacin.find({}):
    if counter > 10:
        break
    # print(data['companyID'])
    list_of_CIN.append(data['companyID'])
    counter+=1

# %%
comp_data = []
for cin in list_of_CIN:
    data = Get_MasterData_From_CIN(cin)
    comp_data.append(data)

# %%
comp_data
# Out:
# [{'cin': 'U18101KL2005PTC018696',
#   'companyName': 'AAA APPARELS PRIVATE LIMITED',
#   'companyStatus': 'Strike Off',
#   'email': 'jayanjayan77@yahoo.com',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '06/10/2005',
#   'registeredAddress': 'DOOR NO:52/UA/3596(1), FIRST FLOOR,VALAVIPADAM CROSS ROAD, RAIL NAGAR, PONNURUNNI, VYTTILA P.O. COCHIN Ernakulam KL 682019 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Ernakulam',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2020'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2019'}]},
#  {'cin': 'U21091UP1995PLC018288',
#   'companyName': 'AAA PAPER MARKETING LIMITED',
#   'companyStatus': 'Not available for efiling',
#   'email': '',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '22/06/1995',
#   'registeredAddress': '4TH K.M.STON, NAJIBABADSTORAGE,KIRAT PUR, BAJNOR BAJNOR Bijnor UP 000000 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Kanpur',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2020'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2019'}]},
#  {},
#  {'cin': 'U32202DL1996PTC082729',
#   'companyName': 'AAA MARKETING PRIVATE LIMITED',
#   'companyStatus': 'Strike Off',
#   'email': 'aaamarketing@powersavingsolution.com',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '17/10/1996',
#   'registeredAddress': '309, SOUTH -EX PLAZA II,209, MASJID MOTH, SOUTH EXTENSION-II, NEW DELHI DL 110049 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Delhi',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2020'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2019'}]},
#  {'cin': 'U40300DL2011PTC213885',
#   'companyName': 'AAA ENERGYTECH PRIVATE LIMITED',
#   'companyStatus': 'Active',
#   'email': 'jainashok1123@gmail.com',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '11/02/2011',
#   'registeredAddress': '91, KIRAN VIHAR DELHI East Delhi DL 110092 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Delhi',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': '           10717.00-',
#     'turnOver': '               0.00',
#     'year': '2020'},
#    {'profitLoss': '           10764.00-',
#     'turnOver': '               0.00',
#     'year': '2019'}]},
#  {'cin': 'U45400MH2007PTC170366',
#   'companyName': 'AAA REAL LAND DEVELOPERS PRIVATE LIMITED',
#   'companyStatus': 'Active',
#   'email': 'secretarial.jmgroup@gmail.com',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '27/04/2007',
#   'registeredAddress': '132, Bayside Mall, 1st Floor, Haji Ali, Tardeo Road, Mumbai Mumbai City MH 400034 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Mumbai',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': '              95.00-',
#     'turnOver': '               0.00',
#     'year': '2020'},
#    {'profitLoss': '           87632.00-',
#     'turnOver': '               0.00',
#     'year': '2019'}]},
#  {'cin': 'U51909WB2009PTC137003',
#   'companyName': 'AAA MERCANTILE PRIVATE LIMITED',
#   'companyStatus': 'Active',
#   'email': 'pburman@pamagencies.in',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '21/07/2009',
#   'registeredAddress': '34/1M, BALLYGUNJ CIRCULAR ROAD KOLKATA WB 700019 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Kolkata',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': '               0.00',
#     'turnOver': '               0.00',
#     'year': '2020'},
#    {'profitLoss': '               0.00',
#     'turnOver': '               0.00',
#     'year': '2019'}]},
#  {'cin': 'U65100DL2012PTC246655',
#   'companyName': 'AAA MONEY MANAGEMENT PRIVATE LIMITED',
#   'companyStatus': 'Strike Off',
#   'email': 'firstmishra@gmail.com',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '24/12/2012',
#   'registeredAddress': '4/2942, SHRI RAM COLONY, BEHARI COLONY, DELHI DL 110032 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Delhi',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2020'},
#    {'profitLoss': '           29646.00-',
#     'turnOver': '               0.00',
#     'year': '2019'}]},
#  {'cin': 'U65991TN1992PTC023660',
#   'companyName': 'AAA FAST GROWTH INVESTMENTS PVT. LTD',
#   'companyStatus': 'Strike Off',
#   'email': '',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '19/10/1992',
#   'registeredAddress': '2,I STREET,LUCKY PLAZA,RANGANATHAN ST, T.NAGAR, MADRAS-600017 Chennai TN 000000 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Chennai',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2020'},
#    {'profitLoss': 'NOT AVAILABLE',
#     'turnOver': 'NOT AVAILABLE',
#     'year': '2019'}]},
#  {'cin': 'U70102DL2007PTC160707',
#   'companyName': 'AAA REAL- TEC PRIVATE LIMITED',
#   'companyStatus': 'Active',
#   'email': 'rajivaggl@yahoo.com',
#   'financialAuditStatus': 'NO',
#   'incorporationDate': '19/03/2007',
#   'registeredAddress': 'G-21, FIRST FLOOR, JUNGPURA EXTENSION, NEW DELHI DL 110014 IN',
#   'registeredContactNo': '',
#   'rocCode': 'RoC-Delhi',
#   'financialDetails': [{'profitLoss': 'NOT APPLICABLE',
#     'turnOver': 'NOT APPLICABLE',
#     'year': '2021'},
#    {'profitLoss': '            5136.00-',
#     'turnOver': '               0.00',
#     'year': '2020'},
#    {'profitLoss': '               0.00',
#     'turnOver': '               0.00',
#     'year': '2019'}]}]

# %%
with open("comp_data_master_data.json","w") as fp:
    json.dump(comp_data,fp,indent=4)
